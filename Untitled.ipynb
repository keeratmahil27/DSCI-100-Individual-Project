# %%
library(tidyverse)
library(tidymodels)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ...

# %%
players <- read_csv("Untitled Folder/players.csv")
sessions <- read_csv("Untitled Folder/sessions.csv")
# slice(players, 1)
# slice(sessions, 1)
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# --------------------------------------- PLAYERS DATA ------------------------------------------------

# Quantitative Summary Statitstics
players_summary_quantitative <- players |>
summarise(avg_played_hours = mean(played_hours, na.rm = TRUE), 
          avg_age = mean(Age, na.rm = TRUE),
          min_played_hours = min(played_hours, na.rm = TRUE),
          max_played_hours = max(played_hours, na.rm = TRUE),
          min_age = min(Age, na.rm = TRUE),
        max_age = max(Age, na.rm = TRUE)) |>
round(2)
# players_summary_quantitative

# Qualitative Summary Statistics
Total <- nrow(players)

# count(players, experience) |>
# mutate(percentage = round(n/Total*100, 2))

# count(players, subscribe) |>
# mutate(percentage = round(n/Total*100, 2)) 

# count(players, gender) |>
# mutate(percentage = round(n/Total*100, 2))
# ----------------------------------------------- SESSSIONS DATA ------------------------------------------

# Quantitaive Summary Statistics
sessions_summary_quantitative <- sessions |>
summarise(avg_original_start_time = mean(original_start_time, na.rm = TRUE),
          avg_original_end_time = mean(original_end_time, na.rm = TRUE),
           min_original_start_time = min(original_start_time, na.rm = TRUE),
          max_original_start_time = max(original_start_time, na.rm = TRUE),
           min_original_end_time = min(original_end_time, na.rm = TRUE),
          max_original_end_time = max(original_end_time, na.rm = TRUE)) |>
round(2)
# sessions_summary_quantitative

# %% [markdown]
# ## Part 1:

# %% [markdown]
# ### Players Data:

# %% [markdown]
# - Observations: 196
# - Variables: 7
#
# | Variable     | Type            | Meaning                                       |
# |--------------|-----------------|-----------------------------------------------|
# | Experience   | character (chr) | The experience of the player                  |
# | Subscribe    | logical (lgl)   | If the player is subscribed to the newsletter |
# | hashedEmail  | character (chr) | Email of the player in a privacy safe form    |
# | played_hours | numeric (dbl)   | Number of hours the player played the game    |
# | name         | character (chr) | Name of the player                            |
# | gender       | character (chr) | Gender of the player                          |
# | Age          | numeric (dbl)   | Age of the player                             |
#
# Summary Statistics of Quantitative Data:
#
# | Variable   | Avg   | Min |  Max  |
# |------------|-------|-----|-------|
# |Hours Played| 5.85  | 0   | 223.1 |
# |Age         | 21.14 | 9   | 58    |
#
# Summary Statistics of Qualitative Data:
#
# | experience | #  | percentage |
# |------------|----|------------|
# | Amateur    | 63 | 32.14      |
# | Beginner	 | 35 | 17.86      |
# | Pro        | 14 | 7.14.      |
# | Regular    | 36 | 18.37      |
# | Veteran    | 48 | 24.49      |
#
# | subscribe | #	  | percentage |
# |-----------|-----|------------|
# | FALSE   	| 52  | 26.53      |
# | TRUE      | 144 | 73.47      |
#
# | gender            | #   | percentage |
# |-------------------|-----|------------|
# | Agender           | 2   | 1.02.      |
# | Female            | 37  | 18.88.     |
# | Male              | 124 | 63.27      |
# | Non-binary        | 15  | 7.65       |
# | Other	            | 1	  | 0.51       |
# | Prefer not to say | 11  | 5.61       |
# | Two-Spirited      | 6   | 3.06       |

# %% [markdown]
# ### Sessions Data:

# %% [markdown]
# - Observations: 1535
# - Variables: 5
#
# | Variable            | Type            | Meaning                                     |
# |---------------------|-----------------|---------------------------------------------|
# | Start Time          | character (chr) | The time at which the player begins playing |
# | End Time            | character (chr) | The time at which the player stops playing  |
# | hashedEmail         | character (chr) | Email of the player in a privacy safe form  |
# | Original Start Time | numeric (dbl)   | Start time in a different format            |
# | Original End Time   | numeric (dbl)   | End time in a different format              |
#
# Summary Statistics of Quantitative Data:
#
# | Variable           | Avg      | Min      | Max      |
# |--------------------|----------|----------|----------|
# |Original Start Time | 1.72e+12 | 1.71e+12 | 1.73e+12 |
# |Original End Time   | 1.72e+12 | 1.71e+12 | 1.73e+12 |

# %% [markdown]
# ### Issues:

# %% [markdown]
# - In the sessions data set, the start and end time variables are stored as characters and not numeric variables, and the units for original start and end times are not provided
# - Issues that could arise in both data sets are any observations listed as NA which may go unnoticed due to the large data sets
# -

# %% [markdown]
# ### Data Collection Method:

# %% [markdown]
# - a questionnaire is provided to players before they can play to collect their gender, email, experience, and age
# - other data, such as start and end time, are collected as the player plays on a server designed specifically for the research
# -

# %% [markdown]
# # Part 2:

# %% [markdown]
# Broad Question: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?
#
# Specific Question: Can experience and gender predict whether a player will subscribe to the the game newsletter?
#
# The players.csv dataset will help me address this question by observing the relationships between gender and subscription and experience and subscription. I can also use the data to build a classification model that can predict whether a gamer will subscribe to the newsletter based on these variables.
# The data seems to already be in a tidy format, so the only wrangling needed for the data would be to select for the columns I will be using and removing any observations that may be listed as NA using filter.

# %% [markdown]
# # Part 3:

# %%
players <- read_csv("Untitled Folder/players.csv")
head(players)
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
# ...

# %% [markdown]
# The data is already in a tidy format, as each column is a variable, each row is an observation, and each cell contains one value. Therefore, no tidying is required.

# %%
mean_players <- players |> 
select(where(is.numeric)) |>
map_dfr(mean, na.rm = T) |>
round(2)
# mean_players

# %% [markdown]
# | Variable     | Avg   |
# |--------------|-------|
# | played_hours | 5.85  |
# | Age          | 21.14 |

# %%
gender_and_subscribe <- players |>
ggplot(aes(x = gender, fill = subscribe)) +
    geom_bar(position = "fill", color = "black") +
    labs( x = "Gender", y = "Count", fill = "Subscribed", title = "Gender vs. Subscription") +
    theme(axis.text.x = element_text(angle = 50, hjust = 1))
gender_and_subscribe

experience_and_subscribe <- players |>
ggplot(aes(x = experience, fill = subscribe)) +
    geom_bar(position = "fill", color = "black") +
    labs( x = "Expeprience", y = "Count", fill = "Subscribed", title = "Experience vs. Subscription")
experience_and_subscribe

gender <- players |>
ggplot(aes(x = gender, fill = gender)) +
    geom_bar(color = "black") +
    labs( x = "Gender", y = "Count", fill = "Gender", title = "Gender of Players") +
    theme(axis.text.x = element_text(angle = 50, hjust = 1))
gender

experience <- players |>
ggplot(aes(x = experience, fill = experience)) +
    geom_bar(color = "black") +
    labs( x = "Experience", y = "Count", fill = "Experience", title = "Experience of Players")
experience
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# With these visulizations, I observe that the most subscribers are male and amateur players. However, the last two graphs show that majority of players are male and amateurs, so these graphs don't necessarily reflect how gender and experience impact subscription. For example, 100% of Agender players are subscribed to the newsletter, but there are only 2 Agender players, so this is not an accurate reflection of how likely Agender players are to subscribe.

# %% [markdown]
# # Part 4

# %% [markdown]
# (4) Methods and Plan
#
# Propose one method to address your question of interest using the selected dataset and explain why it was chosen. Do not perform any modelling or present results at this stage. We are looking for high-level planning regarding model choice and justifying that choice.
#
# In your explanation, respond to the following questions:
#
# Why is this method appropriate?
#
# Which assumptions are required, if any, to apply the method selected?
#
# What are the potential limitations or weaknesses of the method selected?
#
# How are you going to compare and select the model?
#
# How are you going to process the data to apply the model? For example: Are you splitting the data? How?
#
# How many splits? What proportions will you use for the splits? At what stage will you split? Will there be a validation set? Will you use cross validation?

# %% [markdown]
# To answer my question, I can create a knn classification model that predicts whether a player will subscribe to the newsletter based on their gender and experience using dummy variables. A knn classficiation model is appropriate because it will predict a "class", which in this case is "True" or "False", and no assumptionx are made (such as if the relationship between variables is linear). To begin, 70% of the data would be split into training and the rest into testing. Then, the training data would be split into validation sets using 5 fold cross validation to identify the best K value. Some limitations to this method could result due to the small data set and uneven distribution of the different genders. This could result in the model predicting "True" for all Agender players, since the players data shows that all Agender players are subscribed, which is not necessarily accurate.
